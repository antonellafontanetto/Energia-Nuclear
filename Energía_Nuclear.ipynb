# %% [markdown]
# <a href="https://colab.research.google.com/github/antonellafontanetto/Energia-Nuclear/blob/main/Energ%C3%ADa_Nuclear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Cargar el archivo
df = pd.read_csv('/content/energy-pop-exposure-nuclear-plants-locations_plants.csv')

# Ver primeras filas
print(df.head())
# Out:
#    FID              Region                   Country         Plant  \
# 0    0    Europe - Western                    SWEDEN        AGESTA
# 1    1    Europe - Western                     SPAIN       ALMARAZ
# 2    2     America - Latin                    BRAZIL         ANGRA
# 3    3  America - Northern  UNITED STATES OF AMERICA  ARKANSAS ONE
# 4    4    Europe - Western                     SPAIN          ASCO
#
#    NumReactor   Latitude  Longitude   p90_1200   p00_1200   p10_1200  ...  \
# 0           1  59.206022  18.082872  187382000  188684000  188250000  ...
# 1           2  39.808100  -5.696940  136675000  147718000  163429000  ...
# 2           3 -23.007857 -44.458098   99195200  113894000  127898000  ...
# 3           2  35.310320 -93.231289  117830000  132729000  146482000  ...
# 4           2  41.200000   0.566670  271854000  287134000  308922000  ...
#
#      p10r_600     p90_300     p00_300     p10_300    p90u_300    p00u_300  \
# ...

# %%
df.shape
# Out:
# (276, 61)

# %%
df.columns
# Out:
# Index(['FID', 'Region', 'Country', 'Plant', 'NumReactor', 'Latitude',
#        'Longitude', 'p90_1200', 'p00_1200', 'p10_1200', 'p90u_1200',
#        'p00u_1200', 'p10u_1200', 'p90r_1200', 'p00r_1200', 'p10r_1200',
#        'p90_30', 'p00_30', 'p10_30', 'p90u_30', 'p00u_30', 'p10u_30',
#        'p90r_30', 'p00r_30', 'p10r_30', 'p90_75', 'p00_75', 'p10_75',
#        'p90u_75', 'p00u_75', 'p10u_75', 'p90r_75', 'p00r_75', 'p10r_75',
#        'p90_150', 'p00_150', 'p10_150', 'p90u_150', 'p00u_150', 'p10u_150',
#        'p90r_150', 'p00r_150', 'p10r_150', 'p90_600', 'p00_600', 'p10_600',
#        'p90u_600', 'p00u_600', 'p10u_600', 'p90r_600', 'p00r_600', 'p10r_600',
#        'p90_300', 'p00_300', 'p10_300', 'p90u_300', 'p00u_300', 'p10u_300',
#        'p90r_300', 'p00r_300', 'p10r_300'],
#       dtype='object')

# %%
# Ver nombres de columnas y tipos
print(df.info())

# Ver cuántos valores nulos hay por columna
print(df.isna().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Data columns (total 61 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   FID         276 non-null    int64
#  1   Region      273 non-null    object
#  2   Country     276 non-null    object
#  3   Plant       276 non-null    object
#  4   NumReactor  276 non-null    int64
#  5   Latitude    276 non-null    float64
#  6   Longitude   276 non-null    float64
#  7   p90_1200    276 non-null    int64
#  8   p00_1200    276 non-null    int64
#  9   p10_1200    276 non-null    int64
#  10  p90u_1200   276 non-null    float64
#  11  p00u_1200   276 non-null    float64
#  12  p10u_1200   276 non-null    float64
#  13  p90r_1200   276 non-null    int64
#  14  p00r_1200   276 non-null    int64
#  15  p10r_1200   276 non-null    int64
#  16  p90_30      276 non-null    float64
#  17  p00_30      276 non-null    float64
#  18  p10_30      276 non-null    float64
# ...

# %%
print(df.describe())
# Out:
#               FID  NumReactor    Latitude   Longitude      p90_1200  \
# count  276.000000  276.000000  276.000000  276.000000  2.760000e+02
# mean   137.500000    2.329710   41.464873   -0.833154  2.634335e+08
# std     79.818544    1.533856   13.138551   75.441222  1.640597e+08
# min      0.000000    1.000000  -33.968002 -124.209044  3.558760e+05
# 25%     68.750000    1.000000   35.735645  -77.396385  1.463155e+08
# 50%    137.500000    2.000000   42.839200    4.720832  2.033275e+08
# 75%    206.250000    3.000000   49.579176   30.497974  3.788732e+08
# max    275.000000    9.000000   68.050658  166.539698  8.268430e+08
#
#            p00_1200      p10_1200     p90u_1200     p00u_1200     p10u_1200  \
# count  2.760000e+02  2.760000e+02  2.760000e+02  2.760000e+02  2.760000e+02
# mean   2.816791e+08  2.987191e+08  1.748656e+08  1.861499e+08  1.968991e+08
# std    1.833881e+08  1.994596e+08  9.068376e+07  9.689716e+07  1.015562e+08
# ...

# %%
print(df.columns.tolist())
# Out:
# ['FID', 'Region', 'Country', 'Plant', 'NumReactor', 'Latitude', 'Longitude', 'p90_1200', 'p00_1200', 'p10_1200', 'p90u_1200', 'p00u_1200', 'p10u_1200', 'p90r_1200', 'p00r_1200', 'p10r_1200', 'p90_30', 'p00_30', 'p10_30', 'p90u_30', 'p00u_30', 'p10u_30', 'p90r_30', 'p00r_30', 'p10r_30', 'p90_75', 'p00_75', 'p10_75', 'p90u_75', 'p00u_75', 'p10u_75', 'p90r_75', 'p00r_75', 'p10r_75', 'p90_150', 'p00_150', 'p10_150', 'p90u_150', 'p00u_150', 'p10u_150', 'p90r_150', 'p00r_150', 'p10r_150', 'p90_600', 'p00_600', 'p10_600', 'p90u_600', 'p00u_600', 'p10u_600', 'p90r_600', 'p00r_600', 'p10r_600', 'p90_300', 'p00_300', 'p10_300', 'p90u_300', 'p00u_300', 'p10u_300', 'p90r_300', 'p00r_300', 'p10r_300']

# %%
pip install folium

# %%
import folium
from folium.plugins import MarkerCluster
from branca.element import Template, MacroElement

# Crear mapa base
mapa = folium.Map(location=[20, 0], zoom_start=2, tiles='CartoDB dark_matter')

# Agrupar marcadores
marker_cluster = MarkerCluster().add_to(mapa)

# Agregar cada reactor
for _, row in df.iterrows():
    lat = row['Latitude']
    lon = row['Longitude']
    name = row['Plant']

    if pd.notna(lat) and pd.notna(lon):
        folium.Marker(
            location=[lat, lon],
            popup=f"<b>{name}</b>",
            tooltip=name,
            icon=folium.Icon(color='green', icon='info-sign')
        ).add_to(marker_cluster)

# Agregar título al mapa (HTML embebido)
titulo_html = """
{% macro html(this, kwargs) %}
<div style="position: fixed;
            top: 20px; left: 50px; width: 70%;
            z-index:9999;
            font-size:24px;
            font-weight: bold;
            color: white;
            background-color: rgba(0,0,0,0.3);
            padding: 10px;
            border-radius: 8px;">
    🌍 Mapa Mundial de Reactores Nucleares
</div>
{% endmacro %}
"""

template = Template(titulo_html)
macro = MacroElement()
macro._template = template
mapa.get_root().add_child(macro)

# Mostrar el mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
import folium
from folium.plugins import MarkerCluster
from branca.element import Template, MacroElement

# Crear mapa base con tamaño reducido
mapa = folium.Map(
    location=[20, 0],
    zoom_start=2,
    tiles='CartoDB dark_matter',
    width='70%',       # Ancho reducido
    height='450px'     # Altura reducida
)

# Agrupar marcadores
marker_cluster = MarkerCluster().add_to(mapa)

# Agregar cada reactor
for _, row in df.iterrows():
    lat = row['Latitude']
    lon = row['Longitude']
    name = row['Plant']

    if pd.notna(lat) and pd.notna(lon):
        folium.Marker(
            location=[lat, lon],
            popup=f"<b>{name}</b>",
            tooltip=name,
            icon=folium.Icon(color='green', icon='info-sign')
        ).add_to(marker_cluster)

# Agregar título HTML al mapa
titulo_html = """
{% macro html(this, kwargs) %}
<div style="position: fixed;
            top: 20px; left: 50px; width: auto;
            z-index:9999;
            font-size:20px;
            font-weight: bold;
            color: white;
            background-color: rgba(0,0,0,0.4);
            padding: 10px;
            border-radius: 8px;">
    🌍 Mapa Mundial de Reactores Nucleares
</div>
{% endmacro %}
"""

template = Template(titulo_html)
macro = MacroElement()
macro._template = template
mapa.get_root().add_child(macro)

# Mostrar el mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...
